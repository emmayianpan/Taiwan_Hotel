# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
#Read the ods File
path = "../Raw Data/nov20.ods"
df = pd.read_excel(path, engine="odf")
df.head()
# Out:
#       旅館名稱  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4    Hotel    Area  \
# 0    圓山大飯店         NaN         NaN         NaN         NaN    圓山大飯店  Taipei
# 1    國賓大飯店         NaN         NaN         NaN         NaN    國賓大飯店  Taipei
# 2  台北華國大飯店         NaN         NaN         NaN         NaN  台北華國大飯店  Taipei
# 3  華泰王子大飯店         NaN         NaN         NaN         NaN  華泰王子大飯店  Taipei
# 4    豪景大酒店         NaN         NaN         NaN         NaN    豪景大酒店  Taipei
#
#    Room  Demand  Unnamed: 9  Occupancy          ADR  Unnamed: 12  \
# 0   470    7160         NaN   0.507801  2701.758380          NaN
# 1   422    1802         NaN   0.142338  2140.713651          NaN
# 2   326    3003         NaN   0.307055  3002.648019          NaN
# 3   202    1215         NaN   0.200495  1550.101235          NaN
# 4   209     392         NaN   0.062520  1646.732143          NaN
#
#    Room_Revenue  F&B_Revenue  Total_Revenue
# 0      19344590     51378861       84940511
# 1       3857566     66699663       76356047
# 2       9016952      6832720       16630673
# 3       1883373      8170477       12228316
# 4        645519       374120        1306938

# %%
#Clean Data 
df = pd.DataFrame(df, columns=['Hotel','Area','Room','Demand','Occupancy','ADR','Room_Revenue','F&B_Revenue','Total_Revenue'])
df.head()
# Out:
#      Hotel    Area  Room  Demand  Occupancy          ADR  Room_Revenue  \
# 0    圓山大飯店  Taipei   470    7160   0.507801  2701.758380      19344590
# 1    國賓大飯店  Taipei   422    1802   0.142338  2140.713651       3857566
# 2  台北華國大飯店  Taipei   326    3003   0.307055  3002.648019       9016952
# 3  華泰王子大飯店  Taipei   202    1215   0.200495  1550.101235       1883373
# 4    豪景大酒店  Taipei   209     392   0.062520  1646.732143        645519
#
#    F&B_Revenue  Total_Revenue
# 0     51378861       84940511
# 1     66699663       76356047
# 2      6832720       16630673
# 3      8170477       12228316
# 4       374120        1306938

# %%
Day=30

# %%
#Calculate/Add RevPAR and Demand
df['RevPAR'] = df['Occupancy']*df['ADR']
df['Supply'] = df['Room']*Day
df.tail()
# Out:
#           Hotel    Area  Room  Demand  Occupancy          ADR  Room_Revenue  \
# 118   台東桂田喜來登酒店  Others   290    5699   0.655057  2635.770311      15021255
# 119  長榮桂冠酒店(基隆)  Others   140    3287   0.782619  2413.679951       7933766
# 120       鈺通大飯店  Others   120    1373   0.381389  1771.771304       2432642
# 121       寶華大飯店  Others    78     158   0.067521  1225.202532        193582
# 122        陸島酒店  Others    47     559   0.396454  1553.005367        868130
#
#      F&B_Revenue  Total_Revenue       RevPAR  Supply
# 118     19161135       36722848  1726.581034    8700
# 119      5535902       15828259  1888.991905    4200
# 120      5509322        7959413   675.733889    3600
# 121            0         195582    82.727350    2340
# 122        87440         958820   615.695035    1410

# %%
#Calculate Monthly Room/Supply/Demand/Room Revenue/F&B Revenue/Total Revenue
date = "2020-11-30"
room = df["Room"].sum()
supply = df["Supply"].sum()
demand = round(df['Demand'].sum(),0)
room_revenue = df["Room_Revenue"].sum()
fb_revenue = df["F&B_Revenue"].sum()
total_revenue = df["Total_Revenue"].sum()

# %%
#Calculate Monthly Occupancy/ADR/RevPAR
occ = round((demand/supply),2)
adr = round((room_revenue/demand), 2)
#revpar = round((occ*adr), 2)
revpar = round((room_revenue/supply), 2)

# %%
#Append "Total" Row
df = df.append([{'Hotel': 'Total',
                'Area': 'Total',
                'Room': room,
                'Supply': supply,
                'Occupancy': occ,
                'ADR': adr,
                'Room_Revenue': room_revenue,
                'F&B_Revenue': fb_revenue,
                'Total_Revenue': total_revenue,
                'RevPAR': revpar,
                'Demand': demand}], ignore_index=True)
df.tail()
# Out:
#           Hotel    Area   Room  Demand  Occupancy          ADR  Room_Revenue  \
# 119  長榮桂冠酒店(基隆)  Others    140    3287   0.782619  2413.679951       7933766
# 120       鈺通大飯店  Others    120    1373   0.381389  1771.771304       2432642
# 121       寶華大飯店  Others     78     158   0.067521  1225.202532        193582
# 122        陸島酒店  Others     47     559   0.396454  1553.005367        868130
# 123       Total   Total  27968  359401   0.430000  3473.460000    1248364252
#
#      F&B_Revenue  Total_Revenue       RevPAR  Supply
# 119      5535902       15828259  1888.991905    4200
# 120      5509322        7959413   675.733889    3600
# 121            0         195582    82.727350    2340
# 122        87440         958820   615.695035    1410
# 123   1920506705     3591135543  1487.850000  839040

# %%
#Add "Date" Column 
df['Date'] = date
df.tail()
# Out:
#           Hotel    Area   Room  Demand  Occupancy          ADR  Room_Revenue  \
# 119  長榮桂冠酒店(基隆)  Others    140    3287   0.782619  2413.679951       7933766
# 120       鈺通大飯店  Others    120    1373   0.381389  1771.771304       2432642
# 121       寶華大飯店  Others     78     158   0.067521  1225.202532        193582
# 122        陸島酒店  Others     47     559   0.396454  1553.005367        868130
# 123       Total   Total  27968  359401   0.430000  3473.460000    1248364252
#
#      F&B_Revenue  Total_Revenue       RevPAR  Supply        Date
# 119      5535902       15828259  1888.991905    4200  2020-11-30
# 120      5509322        7959413   675.733889    3600  2020-11-30
# 121            0         195582    82.727350    2340  2020-11-30
# 122        87440         958820   615.695035    1410  2020-11-30
# 123   1920506705     3591135543  1487.850000  839040  2020-11-30

# %%
df['Date'] = pd.to_datetime(df['Date']).dt.to_period('D')

# %%
#Format 'Summary'
df['Date'] = df['Date'].dt.to_timestamp()
#df = df.style.format({'occ':'{:.0%}',
                    #'demand':'{:.0f}',
                    #'adr':'{:.2f}',
                    #'revpar':'{:.2f}'})

# %%
print(df.dtypes)
# Out:
# Hotel                    object
# Area                     object
# Room                      int64
# Demand                    int64
# Occupancy               float64
# ADR                     float64
# Room_Revenue              int64
# F&B_Revenue               int64
# Total_Revenue             int64
# RevPAR                  float64
# Supply                    int64
# Date             datetime64[ns]
# dtype: object

# %% [markdown]
# #Create DataFrame 'Summary'
# summary = pd.DataFrame({
#     'date':date,
#     'room':room,
#     'supply':supply,
#     'demand':demand,
#     'room_revenue': room_revenue,
#     'fb_revenue': fb_revenue,
#     'total_revenue': total_revenue,
#     'occ': occ,
#     'adr': adr,
#     'revpar':revpar
# }, index=[0])
# summary

# %% [markdown]
# #Format Summary
# summary['date'] = pd.to_datetime(summary['date']).dt.to_period('M')
# sep20 = summary.style.format({'occ':'{:.0%}',
#                     'demand':'{:.0f}',
#                     'adr':'{:.2f}',
#                     'revpar':'{:.2f}'})

# %% [markdown]
# sep20

# %% [markdown]
# df.to_excel(r'static\data\2020\sep20.xlsx', index = False, encoding='utf-8-sig')

# %%
df.to_csv(r'..\static\data\2020\nov20.csv', index = False, encoding='utf-8-sig')

# %%
from sqlalchemy import create_engine

# %%
connection_string = "postgres:postgres@localhost:5432/hotel_db"
engine = create_engine(f'postgresql://{connection_string}', encoding = 'utf-8')

# %%
engine.table_names()
# Out:
# ['jan20',
#  'oct20',
#  'nov20',
#  'dec20',
#  'combine20',
#  'feb20',
#  'mar20',
#  'apr20',
#  'may20',
#  'jun20',
#  'jul20',
#  'aug20',
#  'sep20']

# %%
df.to_sql(name='nov20', con=engine, if_exists='append', index=False)
